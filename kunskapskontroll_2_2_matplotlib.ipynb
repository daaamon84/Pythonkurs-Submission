# %% [markdown]
# # Matplotlib
# Read the tutorials: https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
print ("Svar-Figur- och axlar-metoden (explicit interface): Här skapar man figurer och axlar för att göra plottar. Det är flexibelt och bäst för avancerade projekt." )
print ("Svar- Pyplot-metoden (implicit interface): Man använder matplotlib.pyplot för snabb och enkel plotting. Den sköter figurer och axlar åt mig.")
print ("Svar -Rekommenderad metod: Använd figur- och axlar-metoden för bättre kontroll och tydlighet vid komplexa grafer eller flera subplotar.")
# Out:
# Svar-Figur- och axlar-metoden (explicit interface): Här skapar man figurer och axlar för att göra plottar. Det är flexibelt och bäst för avancerade projekt.
# Svar- Pyplot-metoden (implicit interface): Man använder matplotlib.pyplot för snabb och enkel plotting. Den sköter figurer och axlar åt mig.
# Svar -Rekommenderad metod: Använd figur- och axlar-metoden för bättre kontroll och tydlighet vid komplexa grafer eller flera subplotar.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
print ("Figure = Hela ytan där allt skapas, som en tom duk. Det är möjligt att ha flera objekt i samma program")
print ("Axes = Ett särskilt diagramområde i en figur där data visas. En figur kan ha flera områden av denna typ")
print ("Axis = X- och y-axlarna inom ett diagramområde, som visar skalor, etiketter och gränser")
print ("Artist = Allt som visas i en figur, såsom linjer, text, punkter och former. Dessa är grundkomponenter i Matplotlib.")
# Out:
# Figure = Hela ytan där allt skapas, som en tom duk. Det är möjligt att ha flera objekt i samma program
# Axes = Ett särskilt diagramområde i en figur där data visas. En figur kan ha flera områden av denna typ
# Axis = X- och y-axlarna inom ett diagramområde, som visar skalor, etiketter och gränser
# Artist = Allt som visas i en figur, såsom linjer, text, punkter och former. Dessa är grundkomponenter i Matplotlib.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
print ("Svar = Listor eller arrays: Ofta används Python-listor eller arrays från bibliotek som NumPy för x- och y-värden")
print ("Svar = Pandas DataFrames eller Series: Det går också att använda kolumner från en DataFrame eller en Series direkt för att skapa grafer")
# Out:
# Svar = Listor eller arrays: Ofta används Python-listor eller arrays från bibliotek som NumPy för x- och y-värden
# Svar = Pandas DataFrames eller Series: Det går också att använda kolumner från en DataFrame eller en Series direkt för att skapa grafer

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
print ("Object-oriented approach:\n")

import matplotlib.pyplot as plt
import numpy as np

# Datan
x = np.linspace(-4, 4, 100)
y = x**2


fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("y = x^2")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

print ("Pyplot approach:\n")

# Datan
x = np.linspace(-4, 4, 100)
y = x**2

plt.plot(x, y)
plt.title("y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

print ("Objektmetoden, som använder fig och ax, ger mer kontroll, medan Pyplot är enklare och mer rak på sak. Båda metoderna leder till samma resultat.")
# Out:
# Object-oriented approach:
# Matplotlib is building the font cache; this may take a moment.
# Pyplot approach:
# Objektmetoden, som använder fig och ax, ger mer kontroll, medan Pyplot är enklare och mer rak på sak. Båda metoderna leder till samma resultat.

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data för scatter-plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data för bar-plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

#Visning av två plott
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Scatter
ax1.scatter(random_data_x, random_data_y, alpha=0.5, color='purple', label='Scatter data')
ax1.plot(x, y, color='blue', label='y = x^2')
ax1.set_title("Scatter Plot")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.legend()

# Bar 
ax2.bar(names, values, color='red')
ax2.set_title("Bar Plot")
ax2.set_xlabel("Fruit")
ax2.set_ylabel("Quantity")

# Print graf
plt.tight_layout()
plt.show()
